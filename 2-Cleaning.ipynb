# %%
import pandas as pd

# %%
df = pd.read_csv('outputs/praise_data.csv')

# %%
df
# Out:
#                     To            From  \
# 0      VitorMarthendal  iviangita#3204
# 1         fabiosmendes  iviangita#3204
# 2            paulo_c2d       paulo_c2d
# 3          sembrestels     sembrestels
# 4               akrtws       iviangita
# ...                ...             ...
# 12063            eeeit       iviangita
# 12064         cpt_grog       iviangita
# 12065     aidanbrodieo       iviangita
# 12066      adnfx2#9648       iviangita
# 12067           atacas     Quantifiers
#
#                                       Reason for dishing  \
# 0            for pushing to get the Hatch Dashboard out
# 1            for pushing to get the Hatch Dashboard out
# 2      17h of work on polishing the hatch frontend an...
# 3      12h working on adding a timelock in the create...
# 4                                 the TE Academy kickoff
# ...                                                  ...
# 12063  mentioning or retweeting Commons Stack on the ...
# ...

# %%
receivers = df[~df[['IH per Praise', 'IH per person']].isna().all(axis=1)]

# %%
receivers
# Out:
#                     To            From  \
# 0      VitorMarthendal  iviangita#3204
# 1         fabiosmendes  iviangita#3204
# 2            paulo_c2d       paulo_c2d
# 3          sembrestels     sembrestels
# 4               akrtws       iviangita
# ...                ...             ...
# 12063            eeeit       iviangita
# 12064         cpt_grog       iviangita
# 12065     aidanbrodieo       iviangita
# 12066      adnfx2#9648       iviangita
# 12067           atacas     Quantifiers
#
#                                       Reason for dishing  \
# 0            for pushing to get the Hatch Dashboard out
# 1            for pushing to get the Hatch Dashboard out
# 2      17h of work on polishing the hatch frontend an...
# 3      12h working on adding a timelock in the create...
# 4                                 the TE Academy kickoff
# ...                                                  ...
# 12063  mentioning or retweeting Commons Stack on the ...
# ...
